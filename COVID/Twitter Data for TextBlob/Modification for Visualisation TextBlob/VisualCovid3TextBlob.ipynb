# %%
from textblob import TextBlob
import pandas as pd
import numpy as np
import re,string
import chart_studio
import chart_studio.plotly as py
import plotly
import plotly.graph_objs as go
from plotly.offline import iplot
import cufflinks
cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl', offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv("covid3.csv") 
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3449 entries, 0 to 3448
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   User       3449 non-null   object
#  1   Text       3449 non-null   object
#  2   Date       3449 non-null   object
#  3   Retweets   3449 non-null   int64
#  4   Favorites  3449 non-null   int64
#  5   HashTags   3448 non-null   object
#  6   City       3449 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 121.3+ KB
#            User                                               Text  \
# 0          uves  These Days 90 % Population in India are sellin...
# 1  sirajnoorani  884 new #COVID19 positive cases reported in #M...
# 2  sirajnoorani  33 more #COVID19 positive cases have been repo...
# 3  sirajnoorani  92 persons have tested positive for #COVID19 i...
# 4  sirajnoorani  Two persons from Guwahati test #COVID19 positi...
#
#                         Date  Retweets  Favorites  \
# 0  2020-05-16 22:53:31+00:00         0          1
# 1  2020-05-16 21:24:09+00:00         0          0
# 2  2020-05-16 21:23:06+00:00         0          0
# 3  2020-05-16 21:22:50+00:00         0          0
# 4  2020-05-16 21:22:11+00:00         0          0
#
#                                             HashTags    City
# 0       #covid19 #lockdownbusiness #businessfromhome  Mumbai
# 1  #COVID19 #Mumbai #BMC #MumbaiFightsCovid19 #Ca...  Mumbai
# 2                                    #COVID19 #Bihar  Mumbai
# 3                    #COVID19 #Indore #MadhyaPradesh  Mumbai
# 4                                    #COVID19 #Assam  Mumbai

# %%
def clean_tweet(tweet):
    return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', tweet).split())

# %%
def analyze_sentiment(tweet):
    analysis = TextBlob(tweet)
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity ==0:
        return 0
    else:
        return -1

# %%
df['clean_tweet'] = df['Text'].apply(lambda x: clean_tweet(x))
df['Sentiment1'] = df['clean_tweet'].apply(lambda x: analyze_sentiment(x))

# %%
df.head()
# Out:
#            User                                               Text  \
# 0          uves  These Days 90 % Population in India are sellin...
# 1  sirajnoorani  884 new #COVID19 positive cases reported in #M...
# 2  sirajnoorani  33 more #COVID19 positive cases have been repo...
# 3  sirajnoorani  92 persons have tested positive for #COVID19 i...
# 4  sirajnoorani  Two persons from Guwahati test #COVID19 positi...
#
#                         Date  Retweets  Favorites  \
# 0  2020-05-16 22:53:31+00:00         0          1
# 1  2020-05-16 21:24:09+00:00         0          0
# 2  2020-05-16 21:23:06+00:00         0          0
# 3  2020-05-16 21:22:50+00:00         0          0
# 4  2020-05-16 21:22:11+00:00         0          0
#
#                                             HashTags    City  \
# 0       #covid19 #lockdownbusiness #businessfromhome  Mumbai
# 1  #COVID19 #Mumbai #BMC #MumbaiFightsCovid19 #Ca...  Mumbai
# 2                                    #COVID19 #Bihar  Mumbai
# 3                    #COVID19 #Indore #MadhyaPradesh  Mumbai
# 4                                    #COVID19 #Assam  Mumbai
#
#                                          clean_tweet  Sentiment1
# 0  These Days 90 Population in India are selling ...           0
# 1  884 new COVID19 positive cases reported in Mum...           1
# 2  33 more COVID19 positive cases have been repor...           1
# 3  92 persons have tested positive for COVID19 in...           1
# 4  Two persons from Guwahati test COVID19 positiv...           1

# %%
n=2345

print(df['Sentiment1'][n])
df.to_csv('visualcovid3.csv',index=False)
# Out:
# 1

# %%
positive=[]
negative=[]
neut=[]
pos=0
neg=0
neutral=0
index=0
for item in df['Sentiment1']:
    index=index+1
    if item==1:
        pos=pos+1
        positive.insert(index,pos)
        negative.insert(index,neg)
        neut.insert(index,neutral)
        #print("Positive=",pos)
        #positive.append(pos)
    elif item==-1:
        neg=neg+1
        negative.insert(index,neg)
        positive.insert(index,pos)
        neut.insert(index,neutral)
        #print("Negative=",neg)
        #negative.append(neg)
    else:
        neutral=neutral+1
        neut.insert(index,neutral)
        negative.insert(index,neg)
        positive.insert(index,pos)
        #print("Neutral=",neutral)
        #neutral.append(neutral)
print("Positive=",pos)  
print("Negative=",neg)
print("Neutral=",neutral)


    
positive=pd.DataFrame(positive)
positive.columns=['Positive']
data=pd.concat([df,positive],axis=1)
data.to_csv('visualcovid3.csv',index=False)
data.head()

df=pd.read_csv("visualcovid3.csv") 
negative=pd.DataFrame(negative)
negative.columns=['Negative']
data=pd.concat([df,negative],axis=1)
data.to_csv('visualcovid3.csv',index=False)
data.head()

df=pd.read_csv("visualcovid3.csv") 
neutral=pd.DataFrame(neut)
neutral.columns=['Neutral']
data=pd.concat([df,neutral],axis=1)

data.to_csv('visualcovid3.csv',index=False)
data.head()
# Out:
# Positive= 1895
# Negative= 603
# Neutral= 951
#            User                                               Text  \
# 0          uves  These Days 90 % Population in India are sellin...
# 1  sirajnoorani  884 new #COVID19 positive cases reported in #M...
# 2  sirajnoorani  33 more #COVID19 positive cases have been repo...
# 3  sirajnoorani  92 persons have tested positive for #COVID19 i...
# 4  sirajnoorani  Two persons from Guwahati test #COVID19 positi...
#
#                         Date  Retweets  Favorites  \
# 0  2020-05-16 22:53:31+00:00         0          1
# 1  2020-05-16 21:24:09+00:00         0          0
# 2  2020-05-16 21:23:06+00:00         0          0
# 3  2020-05-16 21:22:50+00:00         0          0
# 4  2020-05-16 21:22:11+00:00         0          0
#
#                                             HashTags    City  \
# 0       #covid19 #lockdownbusiness #businessfromhome  Mumbai
# 1  #COVID19 #Mumbai #BMC #MumbaiFightsCovid19 #Ca...  Mumbai
# 2                                    #COVID19 #Bihar  Mumbai
# 3                    #COVID19 #Indore #MadhyaPradesh  Mumbai
# 4                                    #COVID19 #Assam  Mumbai
#
#                                          clean_tweet  Sentiment1  Positive  \
# 0  These Days 90 Population in India are selling ...           0         0
# 1  884 new COVID19 positive cases reported in Mum...           1         1
# 2  33 more COVID19 positive cases have been repor...           1         2
# 3  92 persons have tested positive for COVID19 in...           1         3
# 4  Two persons from Guwahati test COVID19 positiv...           1         4
#
#    Negative  Neutral
# 0         0        1
# 1         0        1
# 2         0        1
# 3         0        1
# 4         0        1

# %%
data.head(15)
# Out:
#               User                                               Text  \
# 0             uves  These Days 90 % Population in India are sellin...
# 1     sirajnoorani  884 new #COVID19 positive cases reported in #M...
# 2     sirajnoorani  33 more #COVID19 positive cases have been repo...
# 3     sirajnoorani  92 persons have tested positive for #COVID19 i...
# 4     sirajnoorani  Two persons from Guwahati test #COVID19 positi...
# 5     sirajnoorani  One person from Sonitpur district has tested #...
# 6     sirajnoorani  #Bihar: Test report of one person who passed a...
# 7   superajnarayan  If you want something you never had You have t...
# 8    Sachins887999  How many of U Agree with this #thoughts #Sunda...
# 9         TheyahaE  Faces of Pune Will be out on 18th may. The yah...
# 10       payaltalk  Yup, but please concentrate on #Mumbai, we are...
# 11   Sachins887999   % True @narendramodi @PMOIndia @AmitShah @Ami...
# 12      mandarkeni  They are dying almost everyday but sadly not o...
# 13  AnybodyCanHelp  There is no finer investment for anyone than o...
# 14   TriptiRTiwari  @MamataOfficial the Most Callous CM &amp; @Off...
#
#                          Date  Retweets  Favorites  \
# 0   2020-05-16 22:53:31+00:00         0          1
# 1   2020-05-16 21:24:09+00:00         0          0
# 2   2020-05-16 21:23:06+00:00         0          0
# 3   2020-05-16 21:22:50+00:00         0          0
# 4   2020-05-16 21:22:11+00:00         0          0
# 5   2020-05-16 21:22:00+00:00         0          0
# 6   2020-05-16 21:21:15+00:00         0          0
# 7   2020-05-16 20:43:51+00:00         0          0
# 8   2020-05-16 19:08:36+00:00         1          1
# 9   2020-05-16 18:53:21+00:00         1          1
# 10  2020-05-16 18:34:43+00:00         0          1
# 11  2020-05-16 18:33:23+00:00         1          1
# 12  2020-05-16 18:13:29+00:00         5         15
# 13  2020-05-16 17:45:47+00:00        12         12
# 14  2020-05-16 17:17:51+00:00         2          8
#
#                                              HashTags    City  \
# 0        #covid19 #lockdownbusiness #businessfromhome  Mumbai
# 1   #COVID19 #Mumbai #BMC #MumbaiFightsCovid19 #Ca...  Mumbai
# 2                                     #COVID19 #Bihar  Mumbai
# 3                     #COVID19 #Indore #MadhyaPradesh  Mumbai
# 4                                     #COVID19 #Assam  Mumbai
# 5                                     #COVID19 #Assam  Mumbai
# 6                                     #Bihar #COVID19  Mumbai
# 7   #lifelessons #lockdown #coronavirus #covid19 #...  Mumbai
# 8   #thoughts #SundayThoughts #sundayvibes #Sunday...  Mumbai
# 9   #theyahaevents #eventing #emma #people #celebr...  Mumbai
# 10                      #Mumbai #COVID19 #Maharashtra  Mumbai
# 11           #COVID19 #Covid_19 #Lockdown3 #Lockdown4  Mumbai
# 12                    #Covid19 #MigrantLabourersDying  Mumbai
# 13              #FoodAid #COVID19 #lockdown #Covid_19  Mumbai
# 14                                           #COVID19  Mumbai
#
#                                           clean_tweet  Sentiment1  Positive  \
# 0   These Days 90 Population in India are selling ...           0         0
# 1   884 new COVID19 positive cases reported in Mum...           1         1
# 2   33 more COVID19 positive cases have been repor...           1         2
# 3   92 persons have tested positive for COVID19 in...           1         3
# 4   Two persons from Guwahati test COVID19 positiv...           1         4
# 5   One person from Sonitpur district has tested C...           1         5
# 6   Bihar Test report of one person who passed awa...           1         6
# 7   If you want something you never had You have t...           0         6
# 8   How many of U Agree with this thoughts SundayT...           1         7
# 9   Faces of Pune Will be out on 18th may The yaha...           0         7
# 10  Yup but please concentrate on Mumbai we are in...           0         7
# 11          True COVID19 Covid 19 Lockdown3 Lockdown4           1         8
# 12  They are dying almost everyday but sadly not o...           1         9
# 13  There is no finer investment for anyone than o...           0         9
# 14  the Most Callous CM amp the Most Inefficient T...           1        10
#
#     Negative  Neutral
# 0          0        1
# 1          0        1
# 2          0        1
# 3          0        1
# 4          0        1
# 5          0        1
# 6          0        1
# 7          0        2
# 8          0        2
# 9          0        3
# 10         0        4
# 11         0        4
# 12         0        4
# 13         0        5
# 14         0        5
