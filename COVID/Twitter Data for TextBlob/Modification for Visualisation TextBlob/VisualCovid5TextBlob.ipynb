# %%
from textblob import TextBlob
import pandas as pd
import numpy as np
import re,string
import chart_studio
import chart_studio.plotly as py
import plotly
import plotly.graph_objs as go
from plotly.offline import iplot
import cufflinks
cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl', offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv("covid5.csv") 
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20847 entries, 0 to 20846
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        20847 non-null  int64
#  1   author_name     20847 non-null  object
#  2   text            20847 non-null  object
#  3   retweet_count   20847 non-null  int64
#  4   favorite_count  20847 non-null  int64
#  5   created_at      20847 non-null  object
#  6   hashtags        20847 non-null  object
#  7   location        15008 non-null  object
#  8   source          20843 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 977.3+ KB
#               tweet_id              author_name  \
# 0  1273403905314086912            water & stone
# 1  1273403456020070400            Dipak chauhan
# 2  1273401771831037953             Gopesh Khare
# 3  1273400980349095946               Hindustani
# 4  1273400881178800128  Col Sanjeev Pant (Retd)
#
#                                                 text  retweet_count  \
# 0  #practice ;\n/\n#stillness inside #paradox ;\n...              0
# 1  RT @_MohitChauhan: Our Day 84 of #feedingstray...             35
# 2  RT @MunnishPuri: 🙏 Hon’ble PM @narendramodi @P...            623
# 3  RT @mr_memer_king: China launch #COVID19India ...              1
# 4  RT @SpfAdmin: https://t.co/LyxhvZy9cS It was a...             30
#
#    favorite_count           created_at  \
# 0               0  2020-06-17 23:55:24
# 1               0  2020-06-17 23:53:37
# 2               0  2020-06-17 23:46:55
# 3               0  2020-06-17 23:43:47
# 4               0  2020-06-17 23:43:23
#
#                                             hashtags          location  \
# 0  [{'text': 'practice', 'indices': [0, 9]}, {'te...               NaN
# 1  [{'text': 'feedingstrays', 'indices': [33, 47]...               NaN
# 2    [{'text': 'COVID19India', 'indices': [70, 83]}]           Gurgaon
# 3    [{'text': 'COVID19India', 'indices': [32, 45]}]             India
# 4  [{'text': 'VocalForLocal', 'indices': [103, 11...  New Delhi, India
#
#                 source
# 0  Twitter for Android
# 1      Twitter Web App
# 2   Twitter for iPhone
# 3            rkydotcom
# 4  Twitter for Android

# %%
def clean_tweet(tweet):
    return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', tweet).split())

# %%
def analyze_sentiment(tweet):
    analysis = TextBlob(tweet)
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity ==0:
        return 0
    else:
        return -1

# %%
df['clean_tweet'] = df['text'].apply(lambda x: clean_tweet(x))
df['Sentiment1'] = df['clean_tweet'].apply(lambda x: analyze_sentiment(x))

# %%
df.head()
# Out:
#               tweet_id              author_name  \
# 0  1273403905314086912            water & stone
# 1  1273403456020070400            Dipak chauhan
# 2  1273401771831037953             Gopesh Khare
# 3  1273400980349095946               Hindustani
# 4  1273400881178800128  Col Sanjeev Pant (Retd)
#
#                                                 text  retweet_count  \
# 0  #practice ;\n/\n#stillness inside #paradox ;\n...              0
# 1  RT @_MohitChauhan: Our Day 84 of #feedingstray...             35
# 2  RT @MunnishPuri: 🙏 Hon’ble PM @narendramodi @P...            623
# 3  RT @mr_memer_king: China launch #COVID19India ...              1
# 4  RT @SpfAdmin: https://t.co/LyxhvZy9cS It was a...             30
#
#    favorite_count           created_at  \
# 0               0  2020-06-17 23:55:24
# 1               0  2020-06-17 23:53:37
# 2               0  2020-06-17 23:46:55
# 3               0  2020-06-17 23:43:47
# 4               0  2020-06-17 23:43:23
#
#                                             hashtags          location  \
# 0  [{'text': 'practice', 'indices': [0, 9]}, {'te...               NaN
# 1  [{'text': 'feedingstrays', 'indices': [33, 47]...               NaN
# 2    [{'text': 'COVID19India', 'indices': [70, 83]}]           Gurgaon
# 3    [{'text': 'COVID19India', 'indices': [32, 45]}]             India
# 4  [{'text': 'VocalForLocal', 'indices': [103, 11...  New Delhi, India
#
#                 source                                        clean_tweet  \
# 0  Twitter for Android  practice stillness inside paradox one handed i...
# 1      Twitter Web App  RT MohitChauhan Our Day 84 of feedingstrays in...
# 2   Twitter for iPhone  RT Hon ble PM COVID19India please try and supp...
# 3            rkydotcom  RT memer king China launch COVID19India And th...
# 4  Twitter for Android  RT It was a stupid idea in the first place Bet...
#
#    Sentiment1
# 0           0
# 1           1
# 2           0
# 3          -1
# 4          -1

# %%
n=234

print(df['Sentiment1'][n])
df.to_csv('visualcovid5.csv',index=False)
# Out:
# -1

# %%
positive=[]
negative=[]
neut=[]
pos=0
neg=0
neutral=0
index=0
for item in df['Sentiment1']:
    index=index+1
    if item==1:
        pos=pos+1
        positive.insert(index,pos)
        negative.insert(index,neg)
        neut.insert(index,neutral)
        #print("Positive=",pos)
        #positive.append(pos)
    elif item==-1:
        neg=neg+1
        negative.insert(index,neg)
        positive.insert(index,pos)
        neut.insert(index,neutral)
        #print("Negative=",neg)
        #negative.append(neg)
    else:
        neutral=neutral+1
        neut.insert(index,neutral)
        negative.insert(index,neg)
        positive.insert(index,pos)
        #print("Neutral=",neutral)
        #neutral.append(neutral)
print("Positive=",pos)  
print("Negative=",neg)
print("Neutral=",neutral)


    
positive=pd.DataFrame(positive)
positive.columns=['Positive']
data=pd.concat([df,positive],axis=1)
data.to_csv('visualcovid5.csv',index=False)
data.head()

df=pd.read_csv("visualcovid5.csv") 
negative=pd.DataFrame(negative)
negative.columns=['Negative']
data=pd.concat([df,negative],axis=1)
data.to_csv('visualcovid5.csv',index=False)
data.head()

df=pd.read_csv("visualcovid5.csv") 
neutral=pd.DataFrame(neut)
neutral.columns=['Neutral']
data=pd.concat([df,neutral],axis=1)

data.to_csv('visualcovid5.csv',index=False)
data.head()
# Out:
# Positive= 8563
# Negative= 4097
# Neutral= 8187
#               tweet_id              author_name  \
# 0  1273403905314086912            water & stone
# 1  1273403456020070400            Dipak chauhan
# 2  1273401771831037953             Gopesh Khare
# 3  1273400980349095946               Hindustani
# 4  1273400881178800128  Col Sanjeev Pant (Retd)
#
#                                                 text  retweet_count  \
# 0  #practice ;\n/\n#stillness inside #paradox ;\n...              0
# 1  RT @_MohitChauhan: Our Day 84 of #feedingstray...             35
# 2  RT @MunnishPuri: 🙏 Hon’ble PM @narendramodi @P...            623
# 3  RT @mr_memer_king: China launch #COVID19India ...              1
# 4  RT @SpfAdmin: https://t.co/LyxhvZy9cS It was a...             30
#
#    favorite_count           created_at  \
# 0               0  2020-06-17 23:55:24
# 1               0  2020-06-17 23:53:37
# 2               0  2020-06-17 23:46:55
# 3               0  2020-06-17 23:43:47
# 4               0  2020-06-17 23:43:23
#
#                                             hashtags          location  \
# 0  [{'text': 'practice', 'indices': [0, 9]}, {'te...               NaN
# 1  [{'text': 'feedingstrays', 'indices': [33, 47]...               NaN
# 2    [{'text': 'COVID19India', 'indices': [70, 83]}]           Gurgaon
# 3    [{'text': 'COVID19India', 'indices': [32, 45]}]             India
# 4  [{'text': 'VocalForLocal', 'indices': [103, 11...  New Delhi, India
#
#                 source                                        clean_tweet  \
# 0  Twitter for Android  practice stillness inside paradox one handed i...
# 1      Twitter Web App  RT MohitChauhan Our Day 84 of feedingstrays in...
# 2   Twitter for iPhone  RT Hon ble PM COVID19India please try and supp...
# 3            rkydotcom  RT memer king China launch COVID19India And th...
# 4  Twitter for Android  RT It was a stupid idea in the first place Bet...
#
#    Sentiment1  Positive  Negative  Neutral
# 0           0         0         0        1
# 1           1         1         0        1
# 2           0         1         0        2
# 3          -1         1         1        2
# 4          -1         1         2        2

# %%
data.head(15)
# Out:
#                tweet_id               author_name  \
# 0   1273403905314086912             water & stone
# 1   1273403456020070400             Dipak chauhan
# 2   1273401771831037953              Gopesh Khare
# 3   1273400980349095946                Hindustani
# 4   1273400881178800128   Col Sanjeev Pant (Retd)
# 5   1273400689104949249                  Mr_rahul
# 6   1273400103156412416                Sanjoy Dan
# 7   1273399694589231104               Deva mishra
# 8   1273399558693945344              Abhijit Jain
# 9   1273398959768133633                 Amit Jain
# 10  1273398267628290048  www.THEPIGEONEXPRESS.com
# 11  1273397630526058498                     Pavan
# 12  1273396358192353280              Deepak Kumar
# 13  1273395640161140737                   Chandan
# 14  1273395076337721350                  Kanthesh
#
#                                                  text  retweet_count  \
# 0   #practice ;\n/\n#stillness inside #paradox ;\n...              0
# 1   RT @_MohitChauhan: Our Day 84 of #feedingstray...             35
# 2   RT @MunnishPuri: 🙏 Hon’ble PM @narendramodi @P...            623
# 3   RT @mr_memer_king: China launch #COVID19India ...              1
# 4   RT @SpfAdmin: https://t.co/LyxhvZy9cS It was a...             30
# 5   China launch #COVID19India \nAnd than killed o...              1
# 6   RT @MunnishPuri: 🙏 Hon’ble PM @narendramodi @P...            623
# 7   RT @shivamprajapa13: If Corona viruse had a fa...             78
# 8   RT @MunnishPuri: 🙏 Hon’ble PM @narendramodi @P...            623
# 9   RT @ShamikaRavi: Average growth rate of ACTIVE...            453
# 10  After underreporting coronavirus death figures...              0
# 11  RT @kvicindia: Go Swadeshi. Go Khadi.\nIt’s ti...             56
# 12  RT @MunnishPuri: 🙏 Hon’ble PM @narendramodi @P...            623
# 13  I pledge not to download Chinese app and purch...              0
# 14  RT @ShamikaRavi: Average growth rate of ACTIVE...            453
#
#     favorite_count           created_at  \
# 0                0  2020-06-17 23:55:24
# 1                0  2020-06-17 23:53:37
# 2                0  2020-06-17 23:46:55
# 3                0  2020-06-17 23:43:47
# 4                0  2020-06-17 23:43:23
# 5                0  2020-06-17 23:42:37
# 6                0  2020-06-17 23:40:17
# 7                0  2020-06-17 23:38:40
# 8                0  2020-06-17 23:38:08
# 9                0  2020-06-17 23:35:45
# 10               0  2020-06-17 23:33:00
# 11               0  2020-06-17 23:30:28
# 12               0  2020-06-17 23:25:25
# 13               0  2020-06-17 23:22:33
# 14               0  2020-06-17 23:20:19
#
#                                              hashtags             location  \
# 0   [{'text': 'practice', 'indices': [0, 9]}, {'te...                  NaN
# 1   [{'text': 'feedingstrays', 'indices': [33, 47]...                  NaN
# 2     [{'text': 'COVID19India', 'indices': [70, 83]}]              Gurgaon
# 3     [{'text': 'COVID19India', 'indices': [32, 45]}]                India
# 4   [{'text': 'VocalForLocal', 'indices': [103, 11...     New Delhi, India
# 5     [{'text': 'COVID19India', 'indices': [13, 26]}]                  NaN
# 6     [{'text': 'COVID19India', 'indices': [70, 83]}]  Melbourne,Australia
# 7   [{'text': 'HindiChiniByeBye', 'indices': [50, ...                  NaN
# 8     [{'text': 'COVID19India', 'indices': [70, 83]}]    New York | Nagpur
# 9    [{'text': 'COVID19India', 'indices': [93, 106]}]       Gurgaon, India
# 10  [{'text': 'India', 'indices': [87, 93]}, {'tex...               online
# 11                                                 []                  NaN
# 12    [{'text': 'COVID19India', 'indices': [70, 83]}]                  NaN
# 13  [{'text': 'Atmanirbhar', 'indices': [72, 84]},...                  NaN
# 14   [{'text': 'COVID19India', 'indices': [93, 106]}]                  NaN
#
#                  source                                        clean_tweet  \
# 0   Twitter for Android  practice stillness inside paradox one handed i...
# 1       Twitter Web App  RT MohitChauhan Our Day 84 of feedingstrays in...
# 2    Twitter for iPhone  RT Hon ble PM COVID19India please try and supp...
# 3             rkydotcom  RT memer king China launch COVID19India And th...
# 4   Twitter for Android  RT It was a stupid idea in the first place Bet...
# 5   Twitter for Android  China launch COVID19India And than killed our ...
# 6    Twitter for iPhone  RT Hon ble PM COVID19India please try and supp...
# 7       Twitter Web App  RT If Corona viruse had a face HindiChiniByeBy...
# 8   Twitter for Android  RT Hon ble PM COVID19India please try and supp...
# 9   Twitter for Android  RT Average growth rate of ACTIVE cases in Indi...
# 10            TweetDeck  After underreporting coronavirus death figures...
# 11  Twitter for Android  RT Go Swadeshi Go Khadi It s time to extend yo...
# 12  Twitter for Android  RT Hon ble PM COVID19India please try and supp...
# 13  Twitter for Android  I pledge not to download Chinese app and purch...
# 14  Twitter for Android  RT Average growth rate of ACTIVE cases in Indi...
#
#     Sentiment1  Positive  Negative  Neutral
# 0            0         0         0        1
# 1            1         1         0        1
# 2            0         1         0        2
# 3           -1         1         1        2
# 4           -1         1         2        2
# 5           -1         1         3        2
# 6            0         1         3        3
# 7            0         1         3        4
# 8            0         1         3        5
# 9           -1         1         4        5
# 10           0         1         4        6
# 11          -1         1         5        6
# 12           0         1         5        7
# 13           0         1         5        8
# 14          -1         1         6        8
